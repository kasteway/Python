# %%
import pandas as pd

# %%
heroes = pd.read_csv('https://thisismetis.github.io/datasets/heroes_information.csv?raw=True', 
                     index_col=0,
                     na_values=[-99, '-']
                    ).dropna(subset=['Weight']).reset_index(drop=True)

# %%
df = pd.read_csv('https://thisismetis.github.io/datasets/heroes_information.csv?raw=True')
df.shape
# Out:
# (734, 11)

# %%
df.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %% [markdown]
# ## Finding Missing Values NaN or Null

# %% [markdown]
# ### .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  734 non-null    int64
#  1   name        734 non-null    object
#  2   Gender      734 non-null    object
#  3   Eye color   734 non-null    object
#  4   Race        734 non-null    object
#  5   Hair color  734 non-null    object
#  6   Height      734 non-null    float64
#  7   Publisher   719 non-null    object
#  8   Skin color  734 non-null    object
#  9   Alignment   734 non-null    object
#  10  Weight      732 non-null    float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 63.2+ KB

# %% [markdown]
# ### .isna().sum()

# %%
df.isna().sum()
# Out:
# Unnamed: 0     0
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         2
# dtype: int64

# %% [markdown]
# ### .isna()

# %%
df.isna()
# Out:
#      Unnamed: 0   name  Gender  Eye color   Race  Hair color  Height  \
# 0         False  False   False      False  False       False   False
# 1         False  False   False      False  False       False   False
# 2         False  False   False      False  False       False   False
# 3         False  False   False      False  False       False   False
# 4         False  False   False      False  False       False   False
# ..          ...    ...     ...        ...    ...         ...     ...
# 729       False  False   False      False  False       False   False
# 730       False  False   False      False  False       False   False
# 731       False  False   False      False  False       False   False
# 732       False  False   False      False  False       False   False
# 733       False  False   False      False  False       False   False
#
#      Publisher  Skin color  Alignment  Weight
# 0        False       False      False   False
# ...

# %%
df.Weight.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 729    False
# 730    False
# 731    False
# 732    False
# 733    False
# Name: Weight, Length: 734, dtype: bool

# %% [markdown]
# ## use Tielda ~.isna()   will allow you to mask the True values from the DF

# %%
~df.Weight.isna()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 729    True
# 730    True
# 731    True
# 732    True
# 733    True
# Name: Weight, Length: 734, dtype: bool

# %%
df[~df.Weight.isna()].shape
# Out:
# (732, 11)

# %%
df[~df.Weight.isna()]
# Out:
#      Unnamed: 0             name  Gender Eye color               Race  \
# 0             0           A-Bomb    Male    yellow              Human
# 1             1       Abe Sapien    Male      blue      Icthyo Sapien
# 2             2         Abin Sur    Male      blue            Ungaran
# 3             3      Abomination    Male     green  Human / Radiation
# 4             4          Abraxas    Male      blue      Cosmic Entity
# ..          ...              ...     ...       ...                ...
# 729         729  Yellowjacket II  Female      blue              Human
# 730         730             Ymir    Male     white        Frost Giant
# 731         731             Yoda    Male     brown     Yoda's species
# 732         732          Zatanna  Female      blue              Human
# 733         733             Zoom    Male       red                  -
#
#            Hair color  Height          Publisher Skin color Alignment  Weight
# ...

# %% [markdown]
# ## Handling Missing Values
# 1. Drop Missing Values
# 2. Impute the medin, mean to replace

# %% [markdown]
# ### .dropna(subset=[''], inplace=True)

# %%
weight_na = df.dropna(subset=['Weight'])
weight_na.shape
# Out:
# (732, 11)

# %%
df.dropna(subset=['Weight'], inplace=True)

# %% [markdown]
# ### .fillna(0) or .fillna(df.Weight.mean())

# %%
df.Weight.fillna(0)

# %%
weight_avg = df.Weight.mean()
weight_avg
# Out:
# 43.8551912568306

# %%
weight_avg_df = df.Weight.fillna(weight_avg)

# %%
weight_avg_df.mean()
# Out:
# 43.8551912568306

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'Gender', 'Eye color', 'Race', 'Hair color',
#        'Height', 'Publisher', 'Skin color', 'Alignment', 'Weight'],
#       dtype='object')

# %% [markdown]
# ## Columns

# %% [markdown]
# ### .rename(columns={Dictionary}, inplace=True)

# %%
df.rename(columns={'Unnamed: 0': 'Index'}, inplace=True)

# %%
df.columns
# Out:
# Index(['Index', 'name', 'Gender', 'Eye color', 'Race', 'Hair color', 'Height',
#        'Publisher', 'Skin color', 'Alignment', 'Weight'],
#       dtype='object')

# %% [markdown]
# ### .columns.str.upper()

# %%
df.columns = df.columns.str.upper()
df.columns
# Out:
# Index(['INDEX', 'NAME', 'GENDER', 'EYE COLOR', 'RACE', 'HAIR COLOR', 'HEIGHT',
#        'PUBLISHER', 'SKIN COLOR', 'ALIGNMENT', 'WEIGHT'],
#       dtype='object')

# %% [markdown]
# ### .astype('float', 'str', 'integer')

# %%
df['Weight'] = df.WEIGHT.astype('float')

# %% [markdown]
# ## .drop('column_name', axis=1, inplace=True) --> 0=Row or 1=Column

# %%
df.drop('INDEX', axis=1)
# Out:
#                 NAME  GENDER EYE COLOR               RACE        HAIR COLOR  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
# ...

# %%
df
# Out:
#      INDEX             NAME  GENDER EYE COLOR               RACE  \
# 0        0           A-Bomb    Male    yellow              Human
# 1        1       Abe Sapien    Male      blue      Icthyo Sapien
# 2        2         Abin Sur    Male      blue            Ungaran
# 3        3      Abomination    Male     green  Human / Radiation
# 4        4          Abraxas    Male      blue      Cosmic Entity
# ..     ...              ...     ...       ...                ...
# 729    729  Yellowjacket II  Female      blue              Human
# 730    730             Ymir    Male     white        Frost Giant
# 731    731             Yoda    Male     brown     Yoda's species
# 732    732          Zatanna  Female      blue              Human
# 733    733             Zoom    Male       red                  -
#
#            HAIR COLOR  HEIGHT          PUBLISHER SKIN COLOR ALIGNMENT  WEIGHT  \
# 0             No Hair   203.0      Marvel Comics          -      good   441.0
# ...

# %% [markdown]
# ## Handling Text

# %% [markdown]
# ### .str.upper()

# %%
df.GENDER = df.GENDER.str.upper()
df
# Out:
#      INDEX             NAME  GENDER EYE COLOR               RACE  \
# 0        0           A-Bomb    MALE    yellow              Human
# 1        1       Abe Sapien    MALE      blue      Icthyo Sapien
# 2        2         Abin Sur    MALE      blue            Ungaran
# 3        3      Abomination    MALE     green  Human / Radiation
# 4        4          Abraxas    MALE      blue      Cosmic Entity
# ..     ...              ...     ...       ...                ...
# 729    729  Yellowjacket II  FEMALE      blue              Human
# 730    730             Ymir    MALE     white        Frost Giant
# 731    731             Yoda    MALE     brown     Yoda's species
# 732    732          Zatanna  FEMALE      blue              Human
# 733    733             Zoom    MALE       red                  -
#
#            HAIR COLOR  HEIGHT          PUBLISHER SKIN COLOR ALIGNMENT  WEIGHT  \
# 0             No Hair   203.0      Marvel Comics          -      good   441.0
# ...

# %% [markdown]
# ### .str.replace("items to remove", 'items to replace with')

# %%
df.RACE.str.replace('/', ' - ')
# Out:
# 0                    Human
# 1            Icthyo Sapien
# 2                  Ungaran
# 3      Human  -  Radiation
# 4            Cosmic Entity
#               ...
# 729                  Human
# 730            Frost Giant
# 731         Yoda's species
# 732                  Human
# 733                      -
# Name: RACE, Length: 734, dtype: object

# %% [markdown]
# ### str.strip() -> Removes whitespace == Spaces, Tabs, New Line Characters

# %%
df.RACE.str.strip()
# Out:
# 0                  Human
# 1          Icthyo Sapien
# 2                Ungaran
# 3      Human / Radiation
# 4          Cosmic Entity
#              ...
# 729                Human
# 730          Frost Giant
# 731       Yoda's species
# 732                Human
# 733                    -
# Name: RACE, Length: 734, dtype: object

# %% [markdown]
# ### .str.contains('words looking for') --> Checking SubStrings

# %%
df.RACE.str.contains('Human')
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 729     True
# 730    False
# 731    False
# 732     True
# 733    False
# Name: RACE, Length: 734, dtype: bool
