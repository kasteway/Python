# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (20, 10)

# %%
df = pd.read_csv('../Pandas/hepatitis.csv')
df.head()
# Out:
#    ID  target  age  gender steroid  antivirals fatigue malaise anorexia  \
# 0   1       2   30       2       1           2       2       2        2
# 1   2       2   50       1       1           2       1       2        2
# 2   3       2   78       1       2           2       1       2        2
# 3   4       2   31       1       ?           1       2       2        2
# 4   5       2   34       1       2           2       2       2        2
#
#   liverBig  ... spleen spiders ascites varices bili  alk sgot albu protime  \
# 0        1  ...      2       2       2       2    1   85   18    4       ?
# 1        1  ...      2       2       2       2  0.9  135   42  3.5       ?
# 2        2  ...      2       2       2       2  0.7   96   32    4       ?
# 3        2  ...      2       2       2       2  0.7   46   52    4      80
# 4        2  ...      2       2       2       2    1    ?  200    4       ?
#
#   histology
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...

# %%
#plt.figure(figsize=(8, 6), dpi=80)

plt.hist(df['sgot'], bins = 10, density=True);

# %% [markdown]
# ## Seaborn Histogram
#
#     sns.histplot(column_name, bins = integer Number , stat= density, kde = True)

# %%
sns.histplot(df['sgot'], bins = 10, stat = 'density', kde = True);

# %%
df.columns
# Out:
# Index(['ID', 'target', 'age', 'gender', 'steroid', 'antivirals', 'fatigue',
#        'malaise', 'anorexia', 'liverBig', 'liverFirm', 'spleen', 'spiders',
#        'ascites', 'varices', 'bili', 'alk', 'sgot', 'albu', 'protime',
#        'histology'],
#       dtype='object')

# %% [markdown]
# ## Barplots
#
#  sns.barplot (x= , y= , data = df_name)

# %% [markdown]
# ### Horizontal

# %%
sns.barplot(x = "target", y = "age", data = df, palette = 'husl');

# %%
sns.barplot(x = "target", y = "age", data = df)
sns.despine()

# %% [markdown]
# ### Vertical BarPlot

# %%
sns.barplot(x = "age", y = "target", data = df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='target'>

# %% [markdown]
# ## KDE Plots
#
#     sns.kdeplot(column_name)

# %%
sns.kdeplot(df['age']);

# %% [markdown]
# ## Box Plots - helpful for evaluating skewed data and Outliers
#
#     sns.boxplot(data = df):

# %%
sns.boxplot(data = df);

sns.despine()

# %%
sns.boxplot(data = df.age);

# %%
sns.boxplot(x = df.age, data = df);

# %% [markdown]
# ## Violin Plots
#
#     sns.violinplot(data = df):

# %%
sns.violinplot(x="age", data=df);

# %%
sns.violinplot(data=df);

# %% [markdown]
# ## Plots to visulaize Relationships
#
#     1. Pair Plots
#     2. Joint Plots

# %%
sns.pairplot(df);

# %%
sns.set_style('darkgrid')

sns.jointplot(x = 'age', y= 'target', kind = 'reg', data=df);

# %% [markdown]
# ## HeatMaps

# %%
avg = df.groupby(by = ['target']).mean()

# %%
sns.heatmap(data = avg, cmap = 'Blues', annot = True);

# %% [markdown]
# ## FacetGrid

# %%
g = sns.FacetGrid(df, col = 'target')

g.map(sns.histplot, 'age');

# %%
sns.set_style('darkgrid')

sns.despine() ---> Remove lines around bars
