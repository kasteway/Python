# %%
import pandas as pd

# %%
df = pd.DataFrame(
    [['Oct 2', 'Run', 20], ['Oct 4', 'Walk', 2], ['Oct 5', 'Run', 25], ['Oct 7', 'Swim', 3],
     ['Oct 10', 'Bike', 30], ['Oct 11', 'Bike', 24], ['Oct 12', 'Walk', 60], ['Oct 14', 'Run', 28]],
    columns=['day', 'exercise', 'minutes'])
df
# Out:
#       day exercise  minutes
# 0   Oct 2      Run       20
# 1   Oct 4     Walk        2
# 2   Oct 5      Run       25
# 3   Oct 7     Swim        3
# 4  Oct 10     Bike       30
# 5  Oct 11     Bike       24
# 6  Oct 12     Walk       60
# 7  Oct 14      Run       28

# %% [markdown]
# ## .groupby() GROUPBY requires what to Group By and what Feature to see

# %%
by_excercise = df.groupby('exercise')
by_excercise

# %% [markdown]
# ### Must select a Feature to perform calculation

# %%
df.groupby('exercise').minutes.mean()
# Out:
# exercise
# Bike    27.000000
# Run     24.333333
# Swim     3.000000
# Walk    31.000000
# Name: minutes, dtype: float64

# %%
by_excercise.minutes.mean()
# Out:
# exercise
# Bike    27.000000
# Run     24.333333
# Swim     3.000000
# Walk    31.000000
# Name: minutes, dtype: float64

# %%
by_excercise.count()
# Out:
#           day  minutes
# exercise
# Bike        2        2
# Run         3        3
# Swim        1        1
# Walk        2        2

# %%
df.groupby('exercise').minutes.describe()
# Out:
#           count       mean        std   min   25%   50%   75%   max
# exercise
# Bike        2.0  27.000000   4.242641  24.0  25.5  27.0  28.5  30.0
# Run         3.0  24.333333   4.041452  20.0  22.5  25.0  26.5  28.0
# Swim        1.0   3.000000        NaN   3.0   3.0   3.0   3.0   3.0
# Walk        2.0  31.000000  41.012193   2.0  16.5  31.0  45.5  60.0

# %% [markdown]
# ### Subset of the Fetures to apply mathmatical calculation

# %%
df.groupby('exercise')[['day', 'minutes']].count()
# Out:
#           day  minutes
# exercise
# Bike        2        2
# Run         3        3
# Swim        1        1
# Walk        2        2

# %%
my_df = pd.DataFrame(
    [['Outdoors', 'Run', 20], ['Indoors', 'Walk', 2], ['Outdoors', 'Run', 25], ['Indoors', 'Swim', 3],
     ['Gym', 'Bike', 30], ['Gym', 'Bike', 24], ['Outdoors', 'Walk', 60], ['Outdoors', 'Run', 28]],
    columns=['location', 'exercise', 'minutes'])
my_df
# Out:
#    location exercise  minutes
# 0  Outdoors      Run       20
# 1   Indoors     Walk        2
# 2  Outdoors      Run       25
# 3   Indoors     Swim        3
# 4       Gym     Bike       30
# 5       Gym     Bike       24
# 6  Outdoors     Walk       60
# 7  Outdoors      Run       28

# %%
my_df["track"] = my_df.exercise.isin(['Run', 'Walk'])
my_df
# Out:
#    location exercise  minutes  track
# 0  Outdoors      Run       20   True
# 1   Indoors     Walk        2   True
# 2  Outdoors      Run       25   True
# 3   Indoors     Swim        3  False
# 4       Gym     Bike       30  False
# 5       Gym     Bike       24  False
# 6  Outdoors     Walk       60   True
# 7  Outdoors      Run       28   True

# %%
my_df.groupby('exercise').minutes.mean()
# Out:
# exercise
# Bike    27.000000
# Run     24.333333
# Swim     3.000000
# Walk    31.000000
# Name: minutes, dtype: float64

# %%
my_df.groupby('location').minutes.mean()
# Out:
# location
# Gym         27.00
# Indoors      2.50
# Outdoors    33.25
# Name: minutes, dtype: float64

# %% [markdown]
# ## .agg() use AGGREGATE to have multiple calculations by giving it a list

# %%
my_df.groupby('exercise').agg(['mean', 'count'])
# Out:
# /var/folders/ff/t0ys9vx11sd6x_rkdf6p8ht40000gq/T/ipykernel_3492/2773307610.py:1: FutureWarning: ['location'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   my_df.groupby('exercise').agg(['mean', 'count'])
#             minutes
#                mean count
# exercise
# Bike      27.000000     2
# Run       24.333333     3
# Swim       3.000000     1
# Walk      31.000000     2

# %% [markdown]
# ## Grouping by multiple fields yields MULTI-INDEX dataframe

# %%
multi_grouped = my_df.groupby(['location','exercise']).minutes.mean()
multi_grouped
# Out:
# location  exercise
# Gym       Bike        27.000000
# Indoors   Swim         3.000000
#           Walk         2.000000
# Outdoors  Run         24.333333
#           Walk        60.000000
# Name: minutes, dtype: float64

# %%
multi_grouped['Indoors']
# Out:
# exercise
# Swim    3.0
# Walk    2.0
# Name: minutes, dtype: float64

# %%
multi_grouped['Indoors']['Walk']
# Out:
# 2.0

# %% [markdown]
# ## RESET_INDEX any groupby object:
# 1. Converts current index to columns (Flattening the data to standard form)
# 2. Sets row index to Integer Values

# %%
multi_grouped2 = my_df.groupby(['location', 'exercise']).minutes.mean().reset_index()
multi_grouped2
# Out:
#    location exercise    minutes
# 0       Gym     Bike  27.000000
# 1   Indoors     Swim   3.000000
# 2   Indoors     Walk   2.000000
# 3  Outdoors      Run  24.333333
# 4  Outdoors     Walk  60.000000

# %% [markdown]
# ## Aggregate using .agg()

# %%
intensity_df = pd.DataFrame(
    [['Outdoors', 'Run', 20, 5], ['Indoors', 'Walk', 2, 8], ['Outdoors', 'Run', 25, 4], ['Indoors', 'Swim', 3, 10],
     ['Gym', 'Bike', 30, 9], ['Gym', 'Bike', 24, 3], ['Outdoors', 'Walk', 60, 4], ['Outdoors', 'Run', 28, 7]],
    columns=['location', 'exercise', 'minutes', 'intensity'])
intensity_df
# Out:
#    location exercise  minutes  intensity
# 0  Outdoors      Run       20          5
# 1   Indoors     Walk        2          8
# 2  Outdoors      Run       25          4
# 3   Indoors     Swim        3         10
# 4       Gym     Bike       30          9
# 5       Gym     Bike       24          3
# 6  Outdoors     Walk       60          4
# 7  Outdoors      Run       28          7

# %%
intensity_df.minutes.agg(['mean', 'max'])
# Out:
# mean    24.0
# max     60.0
# Name: minutes, dtype: float64

# %% [markdown]
# ### Multiple Mathmatical calculations using a list to Aggregate

# %%
intensity_df.agg(['min', 'sum', 'max', 'std', 'count', 'median'])
# Out:
# /var/folders/ff/t0ys9vx11sd6x_rkdf6p8ht40000gq/T/ipykernel_3492/1027145210.py:1: FutureWarning: ['location', 'exercise'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   intensity_df.agg(['min', 'sum', 'max', 'std', 'count', 'median'])
#                                                  location  \
# min                                                   Gym
# sum     OutdoorsIndoorsOutdoorsIndoorsGymGymOutdoorsOu...
# max                                              Outdoors
# std                                                   NaN
# count                                                   8
# median                                                NaN
#
#                              exercise     minutes  intensity
# min                              Bike    2.000000    3.00000
# sum     RunWalkRunSwimBikeBikeWalkRun  192.000000   50.00000
# max                              Walk   60.000000   10.00000
# std                               NaN   18.087091    2.60494
# count                               8    8.000000    8.00000
# median                            NaN   24.500000    6.00000

# %%
intensity_df[['minutes','intensity']].agg(['min', 'sum', 'max', 'std', 'count', 'median'])
# Out:
#            minutes  intensity
# min       2.000000    3.00000
# sum     192.000000   50.00000
# max      60.000000   10.00000
# std      18.087091    2.60494
# count     8.000000    8.00000
# median   24.500000    6.00000

# %% [markdown]
# ## Note, this creates multi-index on both rows and columns

# %%
intensity_df.groupby(['location', 'exercise']).agg(['mean', 'count'])
# Out:
#                      minutes        intensity
#                         mean count       mean count
# location exercise
# Gym      Bike      27.000000     2   6.000000     2
# Indoors  Swim       3.000000     1  10.000000     1
#          Walk       2.000000     1   8.000000     1
# Outdoors Run       24.333333     3   5.333333     3
#          Walk      60.000000     1   4.000000     1

# %% [markdown]
# ## use Dictionary to specify different Math calculation by Feature

# %%
intensity_df.groupby('exercise').agg({'minutes': 'mean', 'intensity': ['std', 'max', 'count']})
# Out:
#             minutes intensity
#                mean       std max count
# exercise
# Bike      27.000000  4.242641   9     2
# Run       24.333333  1.527525   7     3
# Swim       3.000000       NaN  10     1
# Walk      31.000000  2.828427   8     2

# %%
intensity_df
# Out:
#    location exercise  minutes  intensity
# 0  Outdoors      Run       20          5
# 1   Indoors     Walk        2          8
# 2  Outdoors      Run       25          4
# 3   Indoors     Swim        3         10
# 4       Gym     Bike       30          9
# 5       Gym     Bike       24          3
# 6  Outdoors     Walk       60          4
# 7  Outdoors      Run       28          7

# %% [markdown]
# ## Apply Functions to DataFrame

# %%
def minHours(minutes):
    return minutes/60

# %% [markdown]
# ## .apply() use the apply a function to a dataframe

# %%
intensity_df['hours'] = intensity_df.minutes.apply(minHours)
intensity_df
# Out:
#    location exercise  minutes  intensity     hours
# 0  Outdoors      Run       20          5  0.333333
# 1   Indoors     Walk        2          8  0.033333
# 2  Outdoors      Run       25          4  0.416667
# 3   Indoors     Swim        3         10  0.050000
# 4       Gym     Bike       30          9  0.500000
# 5       Gym     Bike       24          3  0.400000
# 6  Outdoors     Walk       60          4  1.000000
# 7  Outdoors      Run       28          7  0.466667

# %% [markdown]
# ## lambda instead of functions but still use the .apply()

# %%
intensity_df['lambda_hours'] = intensity_df.minutes.apply(lambda x: x/60)
intensity_df
# Out:
#    location exercise  minutes  intensity     hours  lambda_hours
# 0  Outdoors      Run       20          5  0.333333      0.333333
# 1   Indoors     Walk        2          8  0.033333      0.033333
# 2  Outdoors      Run       25          4  0.416667      0.416667
# 3   Indoors     Swim        3         10  0.050000      0.050000
# 4       Gym     Bike       30          9  0.500000      0.500000
# 5       Gym     Bike       24          3  0.400000      0.400000
# 6  Outdoors     Walk       60          4  1.000000      1.000000
# 7  Outdoors      Run       28          7  0.466667      0.466667

# %% [markdown]
# ## apply lambda functions to entire dataframe

# %%
df_numeric = intensity_df[['minutes', 'intensity']]
df_numeric
# Out:
#    minutes  intensity
# 0       20          5
# 1        2          8
# 2       25          4
# 3        3         10
# 4       30          9
# 5       24          3
# 6       60          4
# 7       28          7

# %%
df_numeric.mean()
# Out:
# minutes      24.00
# intensity     6.25
# dtype: float64

# %%
df_numeric.agg(['mean', 'std'])
# Out:
#         minutes  intensity
# mean  24.000000    6.25000
# std   18.087091    2.60494

# %% [markdown]
# ### x.mean() aggregates the column and calcultes the mean for the column

# %%
df_numeric.apply(lambda x: x - x.mean())
# Out:
#    minutes  intensity
# 0     -4.0      -1.25
# 1    -22.0       1.75
# 2      1.0      -2.25
# 3    -21.0       3.75
# 4      6.0       2.75
# 5      0.0      -3.25
# 6     36.0      -2.25
# 7      4.0       0.75

# %%
intensity_df
# Out:
#    location exercise  minutes  intensity     hours  lambda_hours
# 0  Outdoors      Run       20          5  0.333333      0.333333
# 1   Indoors     Walk        2          8  0.033333      0.033333
# 2  Outdoors      Run       25          4  0.416667      0.416667
# 3   Indoors     Swim        3         10  0.050000      0.050000
# 4       Gym     Bike       30          9  0.500000      0.500000
# 5       Gym     Bike       24          3  0.400000      0.400000
# 6  Outdoors     Walk       60          4  1.000000      1.000000
# 7  Outdoors      Run       28          7  0.466667      0.466667

# %% [markdown]
# ## .map() opertes ONLY on SERIES & NO AGGREGATION

# %%
intensity_df.exercise.map(lambda x: x[0].lower())
# Out:
# 0    r
# 1    w
# 2    r
# 3    s
# 4    b
# 5    b
# 6    w
# 7    r
# Name: exercise, dtype: object

# %% [markdown]
# ## .map() entries to new values using dictionary

# %%
location_map = {'Outdoors': 'nice_weather', 'Indoors': 'no_sun', 'Gym': 'AirConditioned'}

# %%
intensity_df['locations_renamed'] = intensity_df.location.map(location_map)
intensity_df
# Out:
#    location exercise  minutes  intensity     hours  lambda_hours  \
# 0  Outdoors      Run       20          5  0.333333      0.333333
# 1   Indoors     Walk        2          8  0.033333      0.033333
# 2  Outdoors      Run       25          4  0.416667      0.416667
# 3   Indoors     Swim        3         10  0.050000      0.050000
# 4       Gym     Bike       30          9  0.500000      0.500000
# 5       Gym     Bike       24          3  0.400000      0.400000
# 6  Outdoors     Walk       60          4  1.000000      1.000000
# 7  Outdoors      Run       28          7  0.466667      0.466667
#
#   locations_renamed
# 0      nice_weather
# 1            no_sun
# 2      nice_weather
# 3            no_sun
# 4    AirConditioned
# 5    AirConditioned
# 6      nice_weather
# 7      nice_weather

# %% [markdown]
# ## .applymap() applies to the ENTIRE dataframe and DOESN'T DO aggregation

# %%
text_df = intensity_df[['location', 'exercise']]
text_df
# Out:
#    location exercise
# 0  Outdoors      Run
# 1   Indoors     Walk
# 2  Outdoors      Run
# 3   Indoors     Swim
# 4       Gym     Bike
# 5       Gym     Bike
# 6  Outdoors     Walk
# 7  Outdoors      Run

# %%
text_df.applymap(str.upper)
# Out:
#    location exercise
# 0  OUTDOORS      RUN
# 1   INDOORS     WALK
# 2  OUTDOORS      RUN
# 3   INDOORS     SWIM
# 4       GYM     BIKE
# 5       GYM     BIKE
# 6  OUTDOORS     WALK
# 7  OUTDOORS      RUN
