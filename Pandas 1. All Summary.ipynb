# %%
import pandas as pd

# %% [markdown]
# ## Loading Data
#
# Let's take a look at some data and see how pandas can help us navigate.
#
# This dataset about cereal lives on [Kaggle](https://www.kaggle.com/crawford/80-cereals) and originally comes from [these project datasets](https://perso.telecom-paristech.fr/eagan/class/igr204/datasets).

# %%
df = pd.read_csv('https://bit.ly/2JRmGC2')

# %%
df.shape
# Out:
# (77, 16)

# %%
df.columns
# Out:
# Index(['mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo',
#        'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups', 'rating'],
#       dtype='object')

# %%
df.sample(3, random_state = 9)
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 17               Corn Pops   K    C       110        1    0      90    1.0
# 20  Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 28           Fruitful Bran   K    C       120        3    0     240    5.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 17   13.0      12      20        25      2    1.00  1.00  35.782791
# 20   21.0       0      -1         0      2    1.00  1.00  64.533816
# 28   14.0      12     190        25      3    1.33  0.67  41.015492

# %%
df.tail()
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 72              Triples   G    C       110        2    1     250    0.0
# 73                 Trix   G    C       110        1    1     140    0.0
# 74           Wheat Chex   R    C       100        3    1     230    3.0
# 75             Wheaties   G    C       100        3    1     200    3.0
# 76  Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %% [markdown]
# ### Notice row 4 of Potass == -1 meaning it is NULL
# #### Re-import specifying -1 as null and cerial names as Index

# %%
df = pd.read_csv('https://bit.ly/2JRmGC2', na_values = -1, index_col = 0)

# %% [markdown]
# #### Note, one less feature because Ceral Name is an index not a Feature

# %%
df.shape
# Out:
# (77, 15)

# %% [markdown]
# #### Note, Row 4 now contains "NaN" instead of -1

# %%
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0        25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0         0      3     1.0
# All-Bran                     7.0     5.0   320.0        25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0        25      3     1.0
# Almond Delight              14.0     8.0     NaN        25      3     1.0
#
#                            cups     rating
# name
# 100% Bran                  0.33  68.402973
# 100% Natural Bran          1.00  33.983679
# All-Bran                   0.33  59.425505
# All-Bran with Extra Fiber  0.50  93.704912
# Almond Delight             0.75  34.384843

# %%
df.tail()
# Out:
#                     mfr type  calories  protein  fat  sodium  fiber  carbo  \
# name
# Triples               G    C       110        2    1     250    0.0   21.0
# Trix                  G    C       110        1    1     140    0.0   13.0
# Wheat Chex            R    C       100        3    1     230    3.0   17.0
# Wheaties              G    C       100        3    1     200    3.0   17.0
# Wheaties Honey Gold   G    C       110        2    1     200    1.0   16.0
#
#                      sugars  potass  vitamins  shelf  weight  cups     rating
# name
# Triples                 3.0    60.0        25      3     1.0  0.75  39.106174
# Trix                   12.0    25.0        25      2     1.0  1.00  27.753301
# Wheat Chex              3.0   115.0        25      1     1.0  0.67  49.787445
# Wheaties                3.0   110.0        25      1     1.0  1.00  51.592193
# Wheaties Honey Gold     8.0    60.0        25      1     1.0  0.75  36.187559

# %%
df.sample(3, random_state=9)
# Out:
#                        mfr type  calories  protein  fat  sodium  fiber  carbo  \
# name
# Corn Pops                K    C       110        1    0      90    1.0   13.0
# Cream of Wheat (Quick)   N    H       100        3    0      80    1.0   21.0
# Fruitful Bran            K    C       120        3    0     240    5.0   14.0
#
#                         sugars  potass  vitamins  shelf  weight  cups  \
# name
# Corn Pops                 12.0    20.0        25      2    1.00  1.00
# Cream of Wheat (Quick)     0.0     NaN         0      2    1.00  1.00
# Fruitful Bran             12.0   190.0        25      3    1.33  0.67
#
#                            rating
# name
# Corn Pops               35.782791
# Cream of Wheat (Quick)  64.533816
# Fruitful Bran           41.015492

# %%
df.columns
# Out:
# Index(['mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo',
#        'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups', 'rating'],
#       dtype='object')

# %%
df.dtypes
# Out:
# mfr          object
# type         object
# calories      int64
# protein       int64
# fat           int64
# sodium        int64
# fiber       float64
# carbo       float64
# sugars      float64
# potass      float64
# vitamins      int64
# shelf         int64
# weight      float64
# cups        float64
# rating      float64
# dtype: object

# %%
df.fat.head
# Out:
# name
# 100% Bran                    1
# 100% Natural Bran            5
# All-Bran                     1
# All-Bran with Extra Fiber    0
# Almond Delight               2
#                             ..
# Triples                      1
# Trix                         1
# Wheat Chex                   1
# Wheaties                     1
# Wheaties Honey Gold          1
# Name: fat, Length: 77, dtype: int64

# %%
df['fat']
# Out:
# name
# 100% Bran                    1
# 100% Natural Bran            5
# All-Bran                     1
# All-Bran with Extra Fiber    0
# Almond Delight               2
#                             ..
# Triples                      1
# Trix                         1
# Wheat Chex                   1
# Wheaties                     1
# Wheaties Honey Gold          1
# Name: fat, Length: 77, dtype: int64

# %% [markdown]
# #### NaN can now be noticed in features 7,8,9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, 100% Bran to Wheaties Honey Gold
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   mfr       77 non-null     object
#  1   type      77 non-null     object
#  2   calories  77 non-null     int64
#  3   protein   77 non-null     int64
#  4   fat       77 non-null     int64
#  5   sodium    77 non-null     int64
#  6   fiber     77 non-null     float64
#  7   carbo     76 non-null     float64
#  8   sugars    76 non-null     float64
#  9   potass    75 non-null     float64
#  10  vitamins  77 non-null     int64
#  11  shelf     77 non-null     int64
#  12  weight    77 non-null     float64
#  13  cups      77 non-null     float64
#  14  rating    77 non-null     float64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 11.7+ KB

# %% [markdown]
# ### Summary Statistics

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  76.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.802632
# std     19.484119   1.094790   1.006473   83.832295   2.383364   3.907326
# min     50.000000   1.000000   0.000000    0.000000   0.000000   5.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.500000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  76.000000   75.000000   77.000000  77.000000  77.000000  77.000000
# mean    7.026316   98.666667   28.246753   2.207792   1.029610   0.821039
# std     4.378656   70.410636   22.342523   0.832524   0.150477   0.232716
# min     0.000000   15.000000    0.000000   1.000000   0.500000   0.250000
# 25%     3.000000   42.500000   25.000000   1.000000   1.000000   0.670000
# 50%     7.000000   90.000000   25.000000   2.000000   1.000000   0.750000
# 75%    11.000000  120.000000   25.000000   3.000000   1.000000   1.000000
# max    15.000000  330.000000  100.000000   3.000000   1.500000   1.500000
#
#           rating
# count  77.000000
# mean   42.665705
# std    14.047289
# min    18.042851
# 25%    33.174094
# 50%    40.400208
# 75%    50.828392
# max    93.704912

# %%
df['fat'].mean()
# Out:
# 1.0129870129870129

# %%
df['fat'].median()
# Out:
# 1.0

# %%
df['fat'].std()
# Out:
# 1.0064725594803927

# %%
df['fat'].max()
# Out:
# 5

# %%
df['fat'].min()
# Out:
# 0

# %%
df['fat'].count()
# Out:
# 77

# %% [markdown]
# ### Unique Values of a Feature

# %%
df['rating'].unique()
# Out:
# array([68.402973, 33.983679, 59.425505, 93.704912, 34.384843, 29.509541,
#        33.174094, 37.038562, 49.120253, 53.313813, 18.042851, 50.764999,
#        19.823573, 40.400208, 22.736446, 41.445019, 45.863324, 35.782791,
#        22.396513, 40.448772, 64.533816, 46.895644, 36.176196, 44.330856,
#        32.207582, 31.435973, 58.345141, 40.917047, 41.015492, 28.025765,
#        35.252444, 23.804043, 52.076897, 53.371007, 45.811716, 21.871292,
#        31.072217, 28.742414, 36.523683, 36.471512, 39.241114, 45.328074,
#        26.734515, 54.850917, 37.136863, 34.139765, 30.313351, 40.105965,
#        29.924285, 40.69232 , 59.642837, 30.450843, 37.840594, 41.50354 ,
#        60.756112, 63.005645, 49.511874, 50.828392, 39.259197, 39.7034  ,
#        55.333142, 41.998933, 40.560159, 68.235885, 74.472949, 72.801787,
#        31.230054, 53.131324, 59.363993, 38.839746, 28.592785, 46.658844,
#        39.106174, 27.753301, 49.787445, 51.592193, 36.187559])

# %% [markdown]
# ## Count the number of times a value is in the Feature
# ### Sorted by Descending

# %%
df['rating'].value_counts()
# Out:
# 68.402973    1
# 40.692320    1
# 49.511874    1
# 63.005645    1
# 60.756112    1
#             ..
# 31.435973    1
# 32.207582    1
# 44.330856    1
# 36.176196    1
# 36.187559    1
# Name: rating, Length: 77, dtype: int64

# %% [markdown]
# ## Double Brackets to list Features

# %%
df[['fat', 'sugars']].head()
# Out:
#                            fat  sugars
# name
# 100% Bran                    1     6.0
# 100% Natural Bran            5     8.0
# All-Bran                     1     5.0
# All-Bran with Extra Fiber    0     0.0
# Almond Delight               2     8.0

# %% [markdown]
# ## Loc to use Index Name or Index Numbers [0:22] which is inclusive

# %%
df.loc['Wheat Chex'].head()
# Out:
# mfr           R
# type          C
# calories    100
# protein       3
# fat           1
# Name: Wheat Chex, dtype: object

# %%
df.loc[['Wheat Chex', 'Almond Delight']].head()
# Out:
#                mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# name
# Wheat Chex       R    C       100        3    1     230    3.0   17.0     3.0
# Almond Delight   R    C       110        2    2     200    1.0   14.0     8.0
#
#                 potass  vitamins  shelf  weight  cups     rating
# name
# Wheat Chex       115.0        25      1     1.0  0.67  49.787445
# Almond Delight     NaN        25      3     1.0  0.75  34.384843

# %% [markdown]
# ## Loc use Index Name & Feature Name

# %%
df.loc['Wheat Chex', 'sugars']
# Out:
# 3.0

# %% [markdown]
# #### one index name & multiple features non-consecutive

# %%
df.loc['Wheat Chex', ['sugars', 'rating']]
# Out:
# sugars          3.0
# rating    49.787445
# Name: Wheat Chex, dtype: object

# %% [markdown]
# ### multiple index names in slices & multiple Feature slices

# %%
df.loc['Wheat Chex' : 'Wheaties Honey Gold' , 'sugars':'rating']
# Out:
#                      sugars  potass  vitamins  shelf  weight  cups     rating
# name
# Wheat Chex              3.0   115.0        25      1     1.0  0.67  49.787445
# Wheaties                3.0   110.0        25      1     1.0  1.00  51.592193
# Wheaties Honey Gold     8.0    60.0        25      1     1.0  0.75  36.187559

# %% [markdown]
# ### all of the index names & specific multiple Feature names

# %%
df.loc[: , 'sugars':'rating']
# Out:
#                            sugars  potass  vitamins  shelf  weight  cups  \
# name
# 100% Bran                     6.0   280.0        25      3     1.0  0.33
# 100% Natural Bran             8.0   135.0         0      3     1.0  1.00
# All-Bran                      5.0   320.0        25      3     1.0  0.33
# All-Bran with Extra Fiber     0.0   330.0        25      3     1.0  0.50
# Almond Delight                8.0     NaN        25      3     1.0  0.75
# ...                           ...     ...       ...    ...     ...   ...
# Triples                       3.0    60.0        25      3     1.0  0.75
# Trix                         12.0    25.0        25      2     1.0  1.00
# Wheat Chex                    3.0   115.0        25      1     1.0  0.67
# Wheaties                      3.0   110.0        25      1     1.0  1.00
# Wheaties Honey Gold           8.0    60.0        25      1     1.0  0.75
#
#                               rating
# name
# 100% Bran                  68.402973
# 100% Natural Bran          33.983679
# All-Bran                   59.425505
# All-Bran with Extra Fiber  93.704912
# Almond Delight             34.384843
# ...                              ...
# Triples                    39.106174
# Trix                       27.753301
# Wheat Chex                 49.787445
# Wheaties                   51.592193
# Wheaties Honey Gold        36.187559
#
# [77 rows x 7 columns]

# %% [markdown]
# ## iloc to call by Integer Positions is NON-INCLUSIVE

# %%
df.iloc[:3]
# Out:
#                   mfr type  calories  protein  fat  sodium  fiber  carbo  \
# name
# 100% Bran           N    C        70        4    1     130   10.0    5.0
# 100% Natural Bran   Q    C       120        3    5      15    2.0    8.0
# All-Bran            K    C        70        4    1     260    9.0    7.0
#
#                    sugars  potass  vitamins  shelf  weight  cups     rating
# name
# 100% Bran             6.0   280.0        25      3     1.0  0.33  68.402973
# 100% Natural Bran     8.0   135.0         0      3     1.0  1.00  33.983679
# All-Bran              5.0   320.0        25      3     1.0  0.33  59.425505

# %% [markdown]
# #### iloc multiple integer positions and multiple features

# %%
df.iloc[:5, 2:8]
# Out:
#                            calories  protein  fat  sodium  fiber  carbo
# name
# 100% Bran                        70        4    1     130   10.0    5.0
# 100% Natural Bran               120        3    5      15    2.0    8.0
# All-Bran                         70        4    1     260    9.0    7.0
# All-Bran with Extra Fiber        50        4    0     140   14.0    8.0
# Almond Delight                  110        2    2     200    1.0   14.0

# %% [markdown]
# ## Chaining loc & iloc together

# %%
df.iloc[:5]
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0        25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0         0      3     1.0
# All-Bran                     7.0     5.0   320.0        25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0        25      3     1.0
# Almond Delight              14.0     8.0     NaN        25      3     1.0
#
#                            cups     rating
# name
# 100% Bran                  0.33  68.402973
# 100% Natural Bran          1.00  33.983679
# All-Bran                   0.33  59.425505
# All-Bran with Extra Fiber  0.50  93.704912
# Almond Delight             0.75  34.384843

# %%
df.iloc[:5].loc['All-Bran' : 'Almond Delight']
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# All-Bran                     7.0     5.0   320.0        25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0        25      3     1.0
# Almond Delight              14.0     8.0     NaN        25      3     1.0
#
#                            cups     rating
# name
# All-Bran                   0.33  59.425505
# All-Bran with Extra Fiber  0.50  93.704912
# Almond Delight             0.75  34.384843

# %%
df.iloc[:5].loc['All-Bran' : 'Almond Delight'].sodium
# Out:
# name
# All-Bran                     260
# All-Bran with Extra Fiber    140
# Almond Delight               200
# Name: sodium, dtype: int64

# %%
df.iloc[:5].loc['All-Bran' : 'Almond Delight'].sodium.mean()
# Out:
# 200.0

# %% [markdown]
# ## Mathematical Operations

# %%
df['sugars_double']  = df['sugars'] *2
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0        25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0         0      3     1.0
# All-Bran                     7.0     5.0   320.0        25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0        25      3     1.0
# Almond Delight              14.0     8.0     NaN        25      3     1.0
#
#                            cups     rating  sugars_double
# name
# 100% Bran                  0.33  68.402973           12.0
# 100% Natural Bran          1.00  33.983679           16.0
# All-Bran                   0.33  59.425505           10.0
# All-Bran with Extra Fiber  0.50  93.704912            0.0
# Almond Delight             0.75  34.384843           16.0

# %%
df['sugars_double']/df['sugars'] + 5
# Out:
# name
# 100% Bran                    7.0
# 100% Natural Bran            7.0
# All-Bran                     7.0
# All-Bran with Extra Fiber    NaN
# Almond Delight               7.0
#                             ...
# Triples                      7.0
# Trix                         7.0
# Wheat Chex                   7.0
# Wheaties                     7.0
# Wheaties Honey Gold          7.0
# Length: 77, dtype: float64

# %%
df['sugars_double'] >= 11
# Out:
# name
# 100% Bran                     True
# 100% Natural Bran             True
# All-Bran                     False
# All-Bran with Extra Fiber    False
# Almond Delight                True
#                              ...
# Triples                      False
# Trix                          True
# Wheat Chex                   False
# Wheaties                     False
# Wheaties Honey Gold           True
# Name: sugars_double, Length: 77, dtype: bool

# %%
(df['sugars_double'] >= 11) & (df['sugars_double'] == 5)
# Out:
# name
# 100% Bran                    False
# 100% Natural Bran            False
# All-Bran                     False
# All-Bran with Extra Fiber    False
# Almond Delight               False
#                              ...
# Triples                      False
# Trix                         False
# Wheat Chex                   False
# Wheaties                     False
# Wheaties Honey Gold          False
# Name: sugars_double, Length: 77, dtype: bool

# %%
df['high_fat'] = (df['sugars_double'] >= 11) & (df['fat'] > 3)
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0        25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0         0      3     1.0
# All-Bran                     7.0     5.0   320.0        25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0        25      3     1.0
# Almond Delight              14.0     8.0     NaN        25      3     1.0
#
#                            cups     rating  sugars_double  high_fat
# name
# 100% Bran                  0.33  68.402973           12.0     False
# 100% Natural Bran          1.00  33.983679           16.0      True
# All-Bran                   0.33  59.425505           10.0     False
# All-Bran with Extra Fiber  0.50  93.704912            0.0     False
# Almond Delight             0.75  34.384843           16.0     False

# %% [markdown]
# ## Sorting occurs by VALUES or INDEX
#
# ## use inplace=True to save the original DF sorted

# %% [markdown]
# ## Sort By VALUES

# %%
df.sort_values('sugars', ascending=False)
# Out:
#                        mfr type  calories  protein  fat  sodium  fiber  carbo  \
# name
# Smacks                   K    C       110        2    1      70    1.0    9.0
# Golden Crisp             P    C       100        2    0      45    0.0   11.0
# Total Raisin Bran        G    C       140        3    1     190    4.0   15.0
# Post Nat. Raisin Bran    P    C       120        3    1     200    6.0   11.0
# Apple Jacks              K    C       110        2    0     125    1.0   11.0
# ...                     ..  ...       ...      ...  ...     ...    ...    ...
# Puffed Wheat             Q    C        50        2    0       0    1.0   10.0
# Puffed Rice              Q    C        50        1    0       0    0.0   13.0
# Cream of Wheat (Quick)   N    H       100        3    0      80    1.0   21.0
# Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0   19.0
# Quaker Oatmeal           Q    H       100        5    2       0    2.7    NaN
#
#                         sugars  potass  vitamins  shelf  weight  cups  \
# name
# Smacks                    15.0    40.0        25      2    1.00  0.75
# Golden Crisp              15.0    40.0        25      1    1.00  0.88
# Total Raisin Bran         14.0   230.0       100      3    1.50  1.00
# Post Nat. Raisin Bran     14.0   260.0        25      3    1.33  0.67
# Apple Jacks               14.0    30.0        25      2    1.00  1.00
# ...                        ...     ...       ...    ...     ...   ...
# Puffed Wheat               0.0    50.0         0      3    0.50  1.00
# Puffed Rice                0.0    15.0         0      3    0.50  1.00
# Cream of Wheat (Quick)     0.0     NaN         0      2    1.00  1.00
# Shredded Wheat 'n'Bran     0.0   140.0         0      1    1.00  0.67
# Quaker Oatmeal             NaN   110.0         0      1    1.00  0.67
#
#                            rating  sugars_double  high_fat
# name
# Smacks                  31.230054           30.0     False
# Golden Crisp            35.252444           30.0     False
# Total Raisin Bran       28.592785           28.0     False
# Post Nat. Raisin Bran   37.840594           28.0     False
# Apple Jacks             33.174094           28.0     False
# ...                           ...            ...       ...
# Puffed Wheat            63.005645            0.0     False
# Puffed Rice             60.756112            0.0     False
# Cream of Wheat (Quick)  64.533816            0.0     False
# Shredded Wheat 'n'Bran  74.472949            0.0     False
# Quaker Oatmeal          50.828392            NaN     False
#
# [77 rows x 17 columns]

# %%
df.sort_values(['sugars', 'fat'], ascending=False)
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# Smacks                      K    C       110        2    1      70    1.0
# Golden Crisp                P    C       100        2    0      45    0.0
# Post Nat. Raisin Bran       P    C       120        3    1     200    6.0
# Total Raisin Bran           G    C       140        3    1     190    4.0
# Apple Jacks                 K    C       110        2    0     125    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Puffed Wheat                Q    C        50        2    0       0    1.0
# Shredded Wheat              N    C        80        2    0       0    3.0
# Shredded Wheat 'n'Bran      N    C        90        3    0       0    4.0
# Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# Quaker Oatmeal              Q    H       100        5    2       0    2.7
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# Smacks                       9.0    15.0    40.0        25      2    1.00
# Golden Crisp                11.0    15.0    40.0        25      1    1.00
# Post Nat. Raisin Bran       11.0    14.0   260.0        25      3    1.33
# Total Raisin Bran           15.0    14.0   230.0       100      3    1.50
# Apple Jacks                 11.0    14.0    30.0        25      2    1.00
# ...                          ...     ...     ...       ...    ...     ...
# Puffed Wheat                10.0     0.0    50.0         0      3    0.50
# Shredded Wheat              16.0     0.0    95.0         0      1    0.83
# Shredded Wheat 'n'Bran      19.0     0.0   140.0         0      1    1.00
# Shredded Wheat spoon size   20.0     0.0   120.0         0      1    1.00
# Quaker Oatmeal               NaN     NaN   110.0         0      1    1.00
#
#                            cups     rating  sugars_double  high_fat
# name
# Smacks                     0.75  31.230054           30.0     False
# Golden Crisp               0.88  35.252444           30.0     False
# Post Nat. Raisin Bran      0.67  37.840594           28.0     False
# Total Raisin Bran          1.00  28.592785           28.0     False
# Apple Jacks                1.00  33.174094           28.0     False
# ...                         ...        ...            ...       ...
# Puffed Wheat               1.00  63.005645            0.0     False
# Shredded Wheat             1.00  68.235885            0.0     False
# Shredded Wheat 'n'Bran     0.67  74.472949            0.0     False
# Shredded Wheat spoon size  0.67  72.801787            0.0     False
# Quaker Oatmeal             0.67  50.828392            NaN     False
#
# [77 rows x 17 columns]

# %%
df.sort_values(['sugars', 'fat'], ascending= [False, True])
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# Golden Crisp                P    C       100        2    0      45    0.0
# Smacks                      K    C       110        2    1      70    1.0
# Apple Jacks                 K    C       110        2    0     125    1.0
# Post Nat. Raisin Bran       P    C       120        3    1     200    6.0
# Total Raisin Bran           G    C       140        3    1     190    4.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Puffed Wheat                Q    C        50        2    0       0    1.0
# Shredded Wheat              N    C        80        2    0       0    3.0
# Shredded Wheat 'n'Bran      N    C        90        3    0       0    4.0
# Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# Quaker Oatmeal              Q    H       100        5    2       0    2.7
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# Golden Crisp                11.0    15.0    40.0        25      1    1.00
# Smacks                       9.0    15.0    40.0        25      2    1.00
# Apple Jacks                 11.0    14.0    30.0        25      2    1.00
# Post Nat. Raisin Bran       11.0    14.0   260.0        25      3    1.33
# Total Raisin Bran           15.0    14.0   230.0       100      3    1.50
# ...                          ...     ...     ...       ...    ...     ...
# Puffed Wheat                10.0     0.0    50.0         0      3    0.50
# Shredded Wheat              16.0     0.0    95.0         0      1    0.83
# Shredded Wheat 'n'Bran      19.0     0.0   140.0         0      1    1.00
# Shredded Wheat spoon size   20.0     0.0   120.0         0      1    1.00
# Quaker Oatmeal               NaN     NaN   110.0         0      1    1.00
#
#                            cups     rating  sugars_double  high_fat
# name
# Golden Crisp               0.88  35.252444           30.0     False
# Smacks                     0.75  31.230054           30.0     False
# Apple Jacks                1.00  33.174094           28.0     False
# Post Nat. Raisin Bran      0.67  37.840594           28.0     False
# Total Raisin Bran          1.00  28.592785           28.0     False
# ...                         ...        ...            ...       ...
# Puffed Wheat               1.00  63.005645            0.0     False
# Shredded Wheat             1.00  68.235885            0.0     False
# Shredded Wheat 'n'Bran     0.67  74.472949            0.0     False
# Shredded Wheat spoon size  0.67  72.801787            0.0     False
# Quaker Oatmeal             0.67  50.828392            NaN     False
#
# [77 rows x 17 columns]

# %% [markdown]
# ## SORT BY INDEX

# %%
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0   280.0        25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0         0      3     1.0
# All-Bran                     7.0     5.0   320.0        25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0        25      3     1.0
# Almond Delight              14.0     8.0     NaN        25      3     1.0
#
#                            cups     rating  sugars_double  high_fat
# name
# 100% Bran                  0.33  68.402973           12.0     False
# 100% Natural Bran          1.00  33.983679           16.0      True
# All-Bran                   0.33  59.425505           10.0     False
# All-Bran with Extra Fiber  0.50  93.704912            0.0     False
# Almond Delight             0.75  34.384843           16.0     False

# %%
df.sort_index(ascending=False)
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Trix                        G    C       110        1    1     140    0.0
# Triples                     G    C       110        2    1     250    0.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Almond Delight              R    C       110        2    2     200    1.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# All-Bran                    K    C        70        4    1     260    9.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# 100% Bran                   N    C        70        4    1     130   10.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# Wheaties Honey Gold         16.0     8.0    60.0        25      1     1.0
# Wheaties                    17.0     3.0   110.0        25      1     1.0
# Wheat Chex                  17.0     3.0   115.0        25      1     1.0
# Trix                        13.0    12.0    25.0        25      2     1.0
# Triples                     21.0     3.0    60.0        25      3     1.0
# ...                          ...     ...     ...       ...    ...     ...
# Almond Delight              14.0     8.0     NaN        25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0   330.0        25      3     1.0
# All-Bran                     7.0     5.0   320.0        25      3     1.0
# 100% Natural Bran            8.0     8.0   135.0         0      3     1.0
# 100% Bran                    5.0     6.0   280.0        25      3     1.0
#
#                            cups     rating  sugars_double  high_fat
# name
# Wheaties Honey Gold        0.75  36.187559           16.0     False
# Wheaties                   1.00  51.592193            6.0     False
# Wheat Chex                 0.67  49.787445            6.0     False
# Trix                       1.00  27.753301           24.0     False
# Triples                    0.75  39.106174            6.0     False
# ...                         ...        ...            ...       ...
# Almond Delight             0.75  34.384843           16.0     False
# All-Bran with Extra Fiber  0.50  93.704912            0.0     False
# All-Bran                   0.33  59.425505           10.0     False
# 100% Natural Bran          1.00  33.983679           16.0      True
# 100% Bran                  0.33  68.402973           12.0     False
#
# [77 rows x 17 columns]

# %% [markdown]
# ## Filtering Data using data mask
# ### Data mask provides Boolean values from conditional statements
#
#
# ## Bitwise Operators
#
# ## & --> and
# ## | --> or
# ## ~ --> Complement

# %%
df.shape
# Out:
# (77, 17)

# %%
over_sugar = df[df.sugars_double > 10]
print(over_sugar.shape)
over_sugar.head()
# Out:
# (46, 17)
#                         mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                 N    C        70        4    1     130   10.0
# 100% Natural Bran         Q    C       120        3    5      15    2.0
# Almond Delight            R    C       110        2    2     200    1.0
# Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# Apple Jacks               K    C       110        2    0     125    1.0
#
#                          carbo  sugars  potass  vitamins  shelf  weight  cups  \
# name
# 100% Bran                  5.0     6.0   280.0        25      3     1.0  0.33
# 100% Natural Bran          8.0     8.0   135.0         0      3     1.0  1.00
# Almond Delight            14.0     8.0     NaN        25      3     1.0  0.75
# Apple Cinnamon Cheerios   10.5    10.0    70.0        25      1     1.0  0.75
# Apple Jacks               11.0    14.0    30.0        25      2     1.0  1.00
#
#                             rating  sugars_double  high_fat
# name
# 100% Bran                68.402973           12.0     False
# 100% Natural Bran        33.983679           16.0      True
# Almond Delight           34.384843           16.0     False
# Apple Cinnamon Cheerios  29.509541           20.0     False
# Apple Jacks              33.174094           28.0     False

# %%
over_sugar2 = df[(df.sugars_double > 10) | (df.fat > 4)].sort_values('potass', ascending = False)
print(over_sugar2.shape)
over_sugar2.head()
# Out:
# (46, 17)
#                                        mfr type  calories  protein  fat  \
# name
# 100% Bran                                N    C        70        4    1
# Post Nat. Raisin Bran                    P    C       120        3    1
# Raisin Bran                              K    C       120        3    1
# Total Raisin Bran                        G    C       140        3    1
# Fruit & Fibre Dates; Walnuts; and Oats   P    C       120        3    2
#
#                                         sodium  fiber  carbo  sugars  potass  \
# name
# 100% Bran                                  130   10.0    5.0     6.0   280.0
# Post Nat. Raisin Bran                      200    6.0   11.0    14.0   260.0
# Raisin Bran                                210    5.0   14.0    12.0   240.0
# Total Raisin Bran                          190    4.0   15.0    14.0   230.0
# Fruit & Fibre Dates; Walnuts; and Oats     160    5.0   12.0    10.0   200.0
#
#                                         vitamins  shelf  weight  cups  \
# name
# 100% Bran                                     25      3    1.00  0.33
# Post Nat. Raisin Bran                         25      3    1.33  0.67
# Raisin Bran                                   25      2    1.33  0.75
# Total Raisin Bran                            100      3    1.50  1.00
# Fruit & Fibre Dates; Walnuts; and Oats        25      3    1.25  0.67
#
#                                            rating  sugars_double  high_fat
# name
# 100% Bran                               68.402973           12.0     False
# Post Nat. Raisin Bran                   37.840594           28.0     False
# Raisin Bran                             39.259197           24.0     False
# Total Raisin Bran                       28.592785           28.0     False
# Fruit & Fibre Dates; Walnuts; and Oats  40.917047           20.0     False
